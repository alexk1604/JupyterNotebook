# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Alexander Kleinman__
# ***
# Data scientist

# %% [markdown]
# _I am interested in data science because I like statistics and I like learning the reasons behind why things are the way they are. Data science explains reasons behind things such as the risk of loaning finance to an individual or how to maximise points scored in basketball._

# %% [markdown]
# ### The next operation includes that 1 + 1 is equal to 2

# %%
1+1
# Out:
# 2

# %% [markdown]
# ### Horizontal line separator
# this is the conetn above the separator
# ***
# this is the content below the separator

# %% [markdown]
# ### Bullet
# * Bullet item
#     * Sub bullet item

# %% [markdown]
# ### Numbered list
# 1. Numbered item
# 2. Numbered item
# 3. Numbered item
#     1. sub text
#     2. sub text

# %% [markdown]
# ### Hyper link
# [Ronaldo is washed](https://onefootball.com/en/news/i-wanted-messi-cristiano-ronaldo-rinsed-by-al-nassr-manager-36512900)

# %% [markdown]
# ### Strikethrough
# ~Strike~

# %% [markdown]
# ### Image
# ![Jlingz.jpg](attachment:a1ee0d3b-db67-4a92-a297-8b899f88392f.jpg)

# %% [markdown]
# ### Blocked quotes
# > Blocked quote

# %% [markdown]
# ### Code highlighting
# ```Python
# str = "This is block level code"
# print(str)
# ```

# %% [markdown]
# ### Table
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |
